# %% [markdown]
# > Click vào nút chạy code bên dưới để tải repository Vnstock Agent Guide về môi trường làm việ của bạn (ví dụ ở đây là Google Colab). Bạn cần xem qua cấu trúc tài liệu của repository này để có thể tham chiếu chính xác hướng dẫn cho AI vào các tác vụ cụ thể. Các file hướng dẫn AI cho từng IDE phổ biến trong Vibe Coding đã được cung cấp sẵn trong repository, bạn có thể copy đặt vào thư mục gốc của dự án để AI Agent tự đọc khi khởi động.

# %%
# @title 👇 Click để tải Vnstock Agent Guide
import os
import subprocess

# Tải vnstock-agent-guide về môi trường Colab
repo_url = "https://github.com/vnstock-hq/vnstock-agent-guide/"
repo_dir = "vnstock-agent-guide"

if not os.path.exists(repo_dir):
    print(f"Đang tải {repo_url}...")
    subprocess.run(["git", "clone", repo_url, repo_dir], check=True)
    print("✅ Repository được sao chép thành công!")
else:
    print(f"✅ Repository đã tồn tại ở {repo_dir}. Vui lòng xoá thư mục cũ để sao chép lại!")
# Out:
# Đang tải https://github.com/vnstock-hq/vnstock-agent-guide/...
# ✅ Repository được sao chép thành công!

# %% [markdown]
# ![vnstock-ai-agent-guide-colab.png](data:image/png;base64,...)
