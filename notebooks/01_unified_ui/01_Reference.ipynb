# %% [markdown]
# # Unified UI - Reference Layer (Lớp Dữ Liệu Tham Chiếu)
#
# Notebook này minh hoạ cơ chế truy xuất toàn bộ các phương thức thuộc Reference Domain, ánh xạ chuẩn theo tài liệu chính thức. Lớp Reference cung cấp dữ liệu nền tảng tĩnh, hiếm khi thay đổi theo realtime (ví dụ: thông tin công ty, danh sách mã cổ phiếu/chỉ số, lịch sự kiện, thông tin quỹ, v.v.).
#
# <p>
#   <a href="https://colab.research.google.com/github/vnstock-hq/vnstock-agent-guide/blob/main/notebooks/01_unified_ui/01_Reference.ipynb" target="_blank" style="display:inline-block; vertical-align:middle; margin-left:8px;">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="height:20px; vertical-align:middle;">
#   </a>
#   <a href="https://codespaces.new/vnstock-hq/vnstock-agent-guide" target="_blank" style="display:inline-block; vertical-align:middle;">
#     <img src="https://img.shields.io/badge/Open%20in-GitHub%20Codespaces-blue?logo=github" alt="Open in GitHub Codespaces" style="height:20px; vertical-align:middle;">
#   </a>
# </p>
#
#
# ---
#
# ### Sử dụng với Jupyter Notebook (Trong IDE)
# Khi chạy Jupyter Notebook trực tiếp trong IDE (như Antigravity, VS Code, Cursor), để sử dụng được môi trường ảo `~/.venv`, bạn cần đăng ký nó dưới dạng một Kernel.
#
# <details>
# <summary><b>💡 <i>Click để xem hướng dẫn thiết lập chi tiết</i></b></summary>
# <br>
# Khi chạy Jupyter Notebook trực tiếp trong IDE (như Antigravity, VS Code, Cursor), để sử dụng được môi trường ảo `~/.venv`, bạn cần đăng ký nó dưới dạng một Kernel.
#
# **1. Kích hoạt môi trường ảo**
# (Mặc định do Vnstock Installer tạo ra, bạn có thể chỉnh lại path nếu cài ở vị trí khác)
# ```bash
# # macOS / Linux
# source ~/.venv/bin/activate
# # Windows
# ~\.venv\Scripts\activate
# ```
#
# 2. Cài đặt thư viện kết nối (ipykernel)
#
# ```bash
# python -m pip install ipykernel
# ```
#
# 3. Đăng ký Kernel với Jupyter
#
# ```bash
# python -m ipykernel install --user --name=vnstock-venv --display-name "Python (Vnstock)"
# ```
#
# 4. Chọn Kernel trong IDE
#
# Nhìn góc trên bên phải Notebook, click vào tên Kernel hiện tại (vd: Select Kernel hoặc Python 3.x.x).
# Chọn Python (Vnstock) từ danh sách. (Tải lại cửa sổ nếu chưa thấy bằng tổ hợp phím `Ctrl`/`Cmd` + `Shift` + `P` sau đó tìm lệnh `Developer: Reload Window`).

# %% [markdown]
# ### Khởi động

# %%
from vnstock_data import Reference
from IPython.display import display

# Initialize Reference layer
ref = Reference()

# %% [markdown]
# ### 1. Company Domain (Thông Tin Công Ty)
#
# Cung cấp hồ sơ doanh nghiệp, ban lãnh đạo, cổ đông lớn, công ty con, sự kiện và biên lợi nhuận (margin).

# %% [markdown]
# **Thông tin công ty (Company Info)**

# %%
df = ref.company('TCB').info()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   symbol     sector   industry  \
# 0    TCB  Ngân hàng  Ngân hàng
#
#                                              profile  \
# 0  Ngân hàng Thương mại Cổ phần Kỹ thương Việt Na...
#
#                                              history  charter_capital  \
# 0   - Ngày 27/09/1993: Ngân hàng Thương mại Cổ ph...   70862404140000
#
#    issued_share
# 0    7086240414

# %% [markdown]
# **Danh sách cổ đông lớn (Major Shareholders)**

# %%
df = ref.company('VIC').shareholders()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#                                                 name  total_shares     rate  \
# 0           Công ty Cổ Phần Tập Đoàn Đầu Tư Việt Nam    2520265316  0.32590
# 1  Công ty Cổ phần Đầu tư và Phát triển Đường sắt...     834212369  0.10787
# 2                                    Phạm Nhật Vượng     703848781  0.09101
# 3                                     Phạm Thu Hương     341221050  0.04428
# 4               Công ty Cổ phần Năng lượng Vinenergo     331412806  0.04300
#
#          date
# 0  2026-03-23
# 1  2025-12-31
# 2  2025-12-31
# 3  2026-02-02
# 4  2026-02-02

# %% [markdown]
# **Ban lãnh đạo / Quản lý cấp cao (Officers)**

# %%
df = ref.company('HPG').officers()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#                 name                        position      rate
# 0     Trần Đình Long      Chủ tịch Hội đồng Quản trị  0.257960
# 1    Trần Tuấn Dương  Phó Chủ tịch Hội đồng Quản trị  0.023133
# 2   Nguyễn Mạnh Tuấn  Phó Chủ tịch Hội đồng Quản trị  0.022700
# 3  Nguyễn Ngọc Quang    Thành viên Hội đồng Quản trị  0.016300
# 4     Doãn Gia Cường  Phó Chủ tịch Hội đồng Quản trị  0.012500

# %% [markdown]
# **Danh sách công ty con (Subsidiaries)**

# %%
df = ref.company('VNM').subsidiaries()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#                                            name    rate sub_symbol        type
# 0                Angkor Dairy Products Co., Ltd  1.0000   ANGKORDP  Subsidiary
# 1          Driftwood Dairy Holdings Corporation  1.0000     DRIFTW  Subsidiary
# 2    Lao-Jagro Development Xiengkhouang Co.,ltd  0.9207   LAOJAGRO  Subsidiary
# 3  Công ty TNHH MTV Bò Sữa Thống Nhất Thanh Hoá  1.0000     TNTHCM  Subsidiary
# 4                Công ty Cổ phần Đường Việt Nam     NaN  VIETSUGAR  Subsidiary

# %% [markdown]
# **Tin tức công ty (Company News)**

# %%
df = ref.company('TCB').news()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#         id                                         news_title news_sub_title  \
# 0  9854607  TCB: Nghị quyết HĐQT về phê duyệt hạn mức tín ...
# 1  9823902  Techcombank (TCB) dự kiến lợi nhuận 35.000-37....
# 2  9823877                  TCB: Báo cáo thường niên năm 2025
# 3  9810852       TCB: Tài liệu họp ĐHĐCĐ thường niên năm 2026
# 4  9810851  TCB: Quyết định của HĐQT về việc phê duyệt tha...
#
#   friendly_sub_title                                     news_image_url  \
# 0                     https://cdn.fiingroup.vn/medialib/127889/I/202...
# 1                     https://cdn.fiingroup.vn/medialib/127379/I/202...
# 2                     https://cdn.fiingroup.vn/medialib/127889/I/202...
# 3                     https://cdn.fiingroup.vn/medialib/127889/I/202...
# 4                     https://cdn.fiingroup.vn/medialib/127889/I/202...
#
#                                     news_source_link created_at  \
# 0  https://www.hsx.vn/vi/tin-tuc/tcb-nghi-quyet-h...       None
# ...

# %% [markdown]
# **Lịch sự kiện công ty (Company Events)**

# %%
df = ref.company('TCB').events()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#          id                                 event_title  \
# 0  52151502  TCB - Niêm yết bổ sung 19.830.117 cổ phiếu
# 1     32334   TCB - Niêm yết bổ sung 4.766.268 cổ phiếu
# 2  32542029   TCB - Niêm yết bổ sung 5,272,297 cổ phiếu
# 3  65434292  TCB - Niêm yết bổ sung 21.388.675 cổ phiếu
# 4  17097127   TCB - Niêm yết bổ sung 6,323,716 cổ phiếu
#
#                            en__event_title public_date  issue_date  \
# 0  TCB- Lists additional 19,830,117 shares  2025-02-25  2025-02-14
# 1  TCB - Lists additional 4,766,268 shares  2021-01-06  2021-01-13
# 2   TCB- Lists additional 5,272,297 shares  2024-01-03  2023-12-28
# 3  TCB- Lists additional 21,388,675 shares  2025-11-07  2025-11-04
# 4   TCB- Lists additional 6,323,716 shares  2023-01-03  2022-12-27
#
#                                           source_url event_list_code  ratio  \
# 0  http://fiinpro.com/News/Detail/11473744?lang=v...             AIS    0.0
# ...

# %% [markdown]
# **Tỷ lệ ký quỹ (Margin Ratio) - Hiện đang bảo trì từ nguồn**

# %%
# df = ref.company('TCB').margin_ratio()
# display(df.head() if hasattr(df, 'head') else df)

# %% [markdown]
# ### 2. Equity Domain (Danh Sách Cổ Phiếu)
#
# Tra cứu và phân loại danh sách các mã cổ phiếu đang niêm yết trên thị trường.

# %% [markdown]
# **Toàn bộ danh sách cổ phiếu (All Equities)**

# %%
df = ref.equity.list()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   symbol                                           org_name
# 0    YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
# 1    YEG                     Công ty Cổ phần Tập đoàn Yeah1
# 2    YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 3    YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 4    XPH                    Công ty Cổ phần Xà phòng Hà Nội

# %% [markdown]
# **Cổ phiếu theo nhóm/rổ chỉ số (Equities by Group)**

# %%
df = ref.equity.list_by_group('VN30')
display(df.head() if hasattr(df, 'head') else df)
# Out:
# None

# %% [markdown]
# **Cổ phiếu theo phân từng sàn (Equities by Exchange)**

# %%
df = ref.equity.list_by_exchange()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   symbol exchange   type               organ_short_name  \
# 0    YTC    UPCOM  STOCK                XNK Y tế TP.HCM
# 1    YEG     HOSE  STOCK                 Tập đoàn Yeah1
# 2    YBM     HOSE  STOCK          Khoáng sản CN Yên Bái
# 3    YBC    UPCOM  STOCK  Xi măng và Khoáng sản Yên Bái
# 4    XPH    UPCOM  STOCK                Xà phòng Hà Nội
#
#                                           organ_name product_grp_id icb_code2
# 0  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            UPX      4500
# 1                     Công ty Cổ phần Tập đoàn Yeah1            STO      5500
# 2     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái            STO      1700
# 3      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái            UPX      2300
# 4                    Công ty Cổ phần Xà phòng Hà Nội            UPX      3700

# %% [markdown]
# **Cổ phiếu theo phân ngành ICB (Equities by Industry)**

# %%
df = ref.equity.list_by_industry()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   symbol                         organ_name com_type_code  icb_level icb_code  \
# 0    A32                 Công ty Cổ phần 32            CT          1     3000
# 1    A32                 Công ty Cổ phần 32            CT          2     3700
# 2    A32                 Công ty Cổ phần 32            CT          3     3760
# 3    A32                 Công ty Cổ phần 32            CT          4     3765
# 4    AAA  Công ty Cổ phần Nhựa An Phát Xanh            CT          1     1000
#
#                   icb_name
# 0                     None
# 1  Hàng cá nhân & Gia dụng
# 2             Hàng cá nhân
# 3                 Giầy dép
# 4                     None

# %% [markdown]
# ### 3. Index Domain (Danh Sách Chỉ Số)
#
# Truy xuất danh mục rổ chỉ số, các nhóm chỉ số hỗ trợ và các mã thành phần cấu thành.

# %% [markdown]
# **Toàn bộ danh sách rổ chỉ số (All Indices)**

# %%
df = ref.index.list()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   symbol   name                                        description  \
# 0   VN30   VN30  30 cổ phiếu vốn hóa lớn nhất & thanh khoản tốt...
# 1  VNMID  VNMID   Mid-Cap Index - nhóm cổ phiếu vốn hóa trung bình
# 2  VNSML  VNSML        Small-Cap Index - nhóm cổ phiếu vốn hóa nhỏ
# 3  VN100  VN100              100 cổ phiếu có vốn hoá lớn nhất HOSE
# 4  VNALL  VNALL                   Tất cả cổ phiếu trên HOSE và HNX
#
#           full_name         group  index_id  sector_id
# 0        VN30 Index  HOSE Indices         5        NaN
# 1    VNMidCap Index  HOSE Indices         6        NaN
# 2  VNSmallCap Index  HOSE Indices         7        NaN
# 3       VN100 Index  HOSE Indices         8        NaN
# 4       VNAll Index  HOSE Indices         9        NaN

# %% [markdown]
# **Các nhóm rổ chỉ số (List Index Groups)**

# %%
df = ref.index.groups()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   group_name group_code       category  \
# 0       BOND       BOND     Trái phiếu
# 1         CW         CW    Chứng quyền
# 2        ETF       FUND        ETF/Quỹ
# 3   FU_INDEX        DER      Phái sinh
# 4        HNX        HNX  Sàn giao dịch
#
#                                          description
# 0  Corporate Bond - Trái phiếu doanh nghiệp niêm yết
# 1  Covered Warrant - Chứng quyền phát hành bởi cá...
# 2  Exchange-Traded Fund - Quỹ chỉ số và quỹ trao đổi
# 3                Futures - Hợp đồng tương lai chỉ số
# 4                   Sàn Giao dịch Chứng khoán Hà Nội

# %% [markdown]
# **Các thành phần trong rổ chỉ số cố định (Index Members)**

# %%
df = ref.index.members('VN30')
display(df.head() if hasattr(df, 'head') else df)
# Out:
# 0    ACB
# 1    BID
# 2    CTG
# 3    DGC
# 4    FPT
# Name: symbol, dtype: object

# %% [markdown]
# **Thông tin tổng quan về một rổ chỉ số (Index Info)**

# %%
df = ref.index('VN30').info()
display(df.head() if hasattr(df, 'head') else df)
# Out:
# {'name': 'VN30',
#  'description': '30 cổ phiếu vốn hóa lớn nhất & thanh khoản tốt nhất HOSE',
#  'full_name': 'VN30 Index',
#  'group': 'HOSE Indices',
#  'index_id': 5}

# %% [markdown]
# ### 4. Industry Domain (Ngành Kinh Tế)
#
# Tra cứu các ngành kinh tế chuẩn ICB và phân bổ cổ phiếu trong ngành.

# %% [markdown]
# **Danh sách ngành ICB (ICB Industry List)**

# %%
df = ref.industry.list()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   icb_code                                icb_name  icb_level
# 0     0530                        Sản xuất Dầu khí          3
# 1     0570  Thiết bị, Dịch vụ và Phân phối Dầu khí          3
# 2     1350                                Hóa chất          3
# 3     1730                      Lâm nghiệp và Giấy          3
# 4     1750                                Kim loại          3

# %% [markdown]
# **Cổ phiếu theo nhóm ngành (Stocks grouped by Sectors)**

# %%
df = ref.industry.sectors()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   symbol                         organ_name com_type_code  icb_level icb_code  \
# 0    A32                 Công ty Cổ phần 32            CT          1     3000
# 1    A32                 Công ty Cổ phần 32            CT          2     3700
# 2    A32                 Công ty Cổ phần 32            CT          3     3760
# 3    A32                 Công ty Cổ phần 32            CT          4     3765
# 4    AAA  Công ty Cổ phần Nhựa An Phát Xanh            CT          1     1000
#
#                   icb_name
# 0                     None
# 1  Hàng cá nhân & Gia dụng
# 2             Hàng cá nhân
# 3                 Giầy dép
# 4                     None

# %% [markdown]
# ### 5. Fund Domain (Quỹ Đầu Tư Mở)
#
# Khám phá danh sách các Quỹ mở (Mutual Funds) đang hoạt động.

# %% [markdown]
# **Danh sách quỹ đầu tư mở (List of Mutual Funds)**

# %%
df = ref.fund.list()
display(df.head() if hasattr(df, 'head') else df)
# Out:
# 2026-04-12 00:40:17 - vnstock_data.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 63
# 2026-04-12 00:40:17 - vnstock_data.explorer.fmarket.fund - INFO - Total number of funds currently listed on Fmarket: 63
#      ticker                                         organ_name  \
# 0      DCDS                QUỸ ĐẦU TƯ CHỨNG KHOÁN NĂNG ĐỘNG DC
# 1    SSISCA         QUỸ ĐẦU TƯ LỢI THẾ CẠNH TRANH BỀN VỮNG SSI
# 2     MAGEF  QUỸ ĐẦU TƯ CỔ PHIẾU TĂNG TRƯỞNG MIRAE ASSET VI...
# 3  VCBF-MGF               QUỸ ĐẦU TƯ CỔ PHIẾU TĂNG TRƯỞNG VCBF
# 4  VCBF-BCF                  QUỸ ĐẦU TƯ CỔ PHIẾU HÀNG ĐẦU VCBF
#
#                                     organ_short_name    fund_type  \
# 0  CÔNG TY CỔ PHẦN QUẢN LÝ QUỸ DRAGON CAPITAL VIỆ...  equity_fund
# 1                       CÔNG TY TNHH QUẢN LÝ QUỸ SSI  equity_fund
# 2      CÔNG TY TNHH QUẢN LÝ QUỸ MIREA ASSET VIỆT NAM  equity_fund
# 3  CÔNG TY TNHH QUẢN LÝ QUỸ ĐẦU TƯ CHỨNG KHOÁN VI...  equity_fund
# ...

# %% [markdown]
# ### 6. ETF Domain (Quỹ Hoán Đổi Danh Mục)
#
# Truy cập thông tin danh sách các Quỹ Hoán Đổi Danh Mục (ETF) niêm yết.

# %% [markdown]
# **Danh sách quỹ ETF (List of ETFs)**

# %%
df = ref.etf.list()
display(df.head() if hasattr(df, 'head') else df)
# Out:
# 0    E1VFVN30
# 1    FUCTVGF3
# 2    FUCTVGF4
# 3    FUCTVGF5
# 4    FUCVREIT
# Name: symbol, dtype: object

# %% [markdown]
# ### 7. Bond Domain (Trái Phiếu)
#
# Liệt kê danh sách các trái phiếu chính phủ và trái phiếu doanh nghiệp trên thị trường.

# %% [markdown]
# **Toàn bộ trái phiếu (All Bonds)**

# %%
df_all = ref.bond.list(bond_type='all')
display(df_all.head() if hasattr(df_all, 'head') else df_all)
# Out:
#       symbol       type
# 0  BAB123032  corporate
# 1  BAB124015  corporate
# 2  BAB124016  corporate
# 3  BAB124024  corporate
# 4  BAB124025  corporate

# %% [markdown]
# **Trái phiếu Doanh nghiệp (Corporate Bonds)**

# %%
df_corp = ref.bond.list(bond_type='corporate')
display(df_corp.head() if hasattr(df_corp, 'head') else df_corp)
# Out:
# 0    BAB123032
# 1    BAB124015
# 2    BAB124016
# 3    BAB124024
# 4    BAB124025
# Name: symbol, dtype: object

# %% [markdown]
# ### 8. Events Domain (Sự Kiện Thị Trường)
#
# Lịch sự kiện thị trường chung như ngày giao dịch không hưởng quyền, đại hội cổ đông, thay đổi vốn, nghỉ lễ.

# %% [markdown]
# **Lịch sự kiện công ty trong tháng (Monthly Corporate Calendar)**

# %%
df = ref.events.calendar(start='2026-03-01', end='2026-03-31')
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   symbol                                   event_name  \
# 0    GTD          Giao dịch nội bộ: Giao dịch tổ chức
# 1    MSB          Giao dịch nội bộ: Giao dịch tổ chức
# 2    SHS          Giao dịch nội bộ: Giao dịch tổ chức
# 3    ILC  Giao dịch nội bộ: Giao dịch người liên quan
# 4    CCS          Giao dịch nội bộ: Giao dịch cá nhân
#
#                                          event_title ex_right_date  \
# 0  Công ty Cổ Phần Đầu Tư Và Phát Triển Thương Mạ...           NaT
# 1  Công ty TNHH MTV - Tổng Công ty Bảo Đảm An Toà...           NaT
# 2                   PYN Elite Fund - Đăng kí Mua SHS           NaT
# 3              Vũ Hoài Nam - Đăng kí Mua 500,000 ILC           NaT
# 4              Đặng Duy Hợp - Đăng kí Mua 20,000 CCS           NaT
#
#   record_date payout_date  value  ratio  \
# 0         NaT         NaT    NaN    NaN
# 1         NaT         NaT    NaN    NaN
# 2         NaT         NaT    NaN    NaN
# 3         NaT         NaT    NaN    NaN
# ...

# %% [markdown]
# **Lọc riêng sự kiện trả cổ tức (Dividend Events)**

# %%
df = ref.events.calendar(start='2026-03-01', end='2026-03-31', event_type='dividend')
display(df.head() if hasattr(df, 'head') else df)
# Out:
#   symbol                event_name  \
# 0    NVL        Phát hành cổ phiếu
# 1    PCT        Phát hành cổ phiếu
# 2    HQC        Phát hành cổ phiếu
# 3    MAC        Phát hành cổ phiếu
# 4    TDM  Trả cổ tức bằng tiền mặt
#
#                                          event_title ex_right_date  \
# 0  Phát hành cổ phiếu - Chuyển từ trái phiếu chuy...    2026-03-31
# 1  Phát hành cổ phiếu - Phát hành riêng lẻ tỉ lệ ...    2026-03-27
# 2  Phát hành cổ phiếu - Phát hành riêng lẻ tỉ lệ ...    2026-03-31
# 3  Phát hành cổ phiếu - Trả Cổ tức bằng Cổ phiếu ...           NaT
# 4  Trả cổ tức bằng tiền mặt - Đợt 1 2025 - 1,300 VND    2026-04-14
#
#   record_date payout_date   value    ratio  \
# 0  2026-03-31         NaT     NaN  0.00111
# 1  2026-03-27         NaT     NaN  0.59960
# 2  2026-03-31         NaT     NaN  0.08670
# 3         NaT         NaT     NaN  0.10000
# 4  2026-04-15  2026-05-29  1300.0  0.13000
#
#                                           organ_name public_date event_type
# ...

# %% [markdown]
# **Lịch giao dịch / Sự kiện đặc biệt toàn thị trường (Market-wide Events)**

# %%
df = ref.events.market()
display(df.head() if hasattr(df, 'head') else df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 10. Futures Domain (Hợp Đồng Tương Lai)
#
# Danh sách và thông tin chi tiết các hợp đồng tương lai chỉ số (Phái sinh).

# %% [markdown]
# **Liệt kê danh sách HĐTL (List of Futures Contracts)**

# %%
df = ref.futures().list()
display(df.head() if hasattr(df, 'head') else df)
# Out:
# 0    41I1G4000
# 1    41I1G5000
# 2    41I1G6000
# 3    41I1G9000
# 4    41I2G4000
# Name: symbol, dtype: object

# %% [markdown]
# **Cấu trúc thông tin cơ bản một HĐTL cố định (Future Contract Info)**

# %%
df = ref.futures('VN30F2503').info()
display(df.head() if hasattr(df, 'head') else df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 11. Warrant Domain (Chứng Quyền Có Bảo Đảm)
#
# Danh mục niêm yết và chi tiết tham số của các Chứng quyền có bảo đảm (Covered Warrants).

# %% [markdown]
# **Liệt kê chứng quyền niêm yết (List of Covered Warrants)**

# %%
df = ref.warrant().list()
display(df.head() if hasattr(df, 'head') else df)
# Out:
# 0    CACB2510
# 1    CACB2511
# 2    CACB2514
# 3    CACB2515
# 4    CACB2516
# Name: symbol, dtype: object

# %% [markdown]
# **Thông số chi tiết một chứng quyền (Warrant Profile Info)**

# %%
df = ref.warrant('CACB2511').info()
display(df.head() if hasattr(df, 'head') else df)
# Out:
#      symbol issuer underlying_symbol  exercise_price exercise_ratio  \
# 0  CACB2511    SSI               ACB            23.0            2:1
#
#   last_trading_date listed_share exchange warrant_type  underlying_price  ...  \
# 0        21/09/2026     13000000     HOSE         Call             23.85  ...
#
#    ceiling_price  floor_price  match_price  total_volume  foreign_room  \
# 0           2.33         0.69         1.51     150159000      12880000
#
#    foreign_buy_volume  foreign_sell_volume  break_even_point  \
# 0                   0                33000             26.02
#
#    break_even_point_diff  intrinsic_value
# 0                   2.17            0.425
#
# [1 rows x 21 columns]

# %% [markdown]
# ## 4. Tra cứu Thông tin & Ký hiệu Quốc tế (Global Search)
#
# Sử dụng domain `Search` để tra cứu thông tin meta-data của các tài sản đa quốc gia (Hàng hóa, Ngoại hối, Crypto).
#
# - `search.symbol()`: Quét toàn bộ metadata nội bộ của FXSB nhằm lấy danh sách hàng ngàn instrument hợp lệ với tốc độ mili-giây.
# - `search.info()`: Cổng định tuyến mapping với MSN (Microsoft Finance) cung cấp tên đầy đủ, mô tả và sàn giao dịch cho tài sản quốc tế.

# %%
print("-- 1. Tìm symbol EUR thông qua FXSB Listing --")
df_search_symbol = ref.search.symbol("EUR")
display(df_search_symbol.head())

print("-- 2. Tìm metadata chi tiết mã AAPL thông qua MSN Global Info --")
df_asset_info = ref.search.info("AAPL")
display(df_asset_info.head())
